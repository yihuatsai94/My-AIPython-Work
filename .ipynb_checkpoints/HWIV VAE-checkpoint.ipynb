# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import some useful packages

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow.keras.backend as K

# %% [markdown]
# ### Layers for FNN

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Lambda, concatenate
from tensorflow.keras.layers import Dense

# %% [markdown]
# ### Optimizers for training

# %%
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras import metrics

# %% [markdown]
# ### Losses for training

# %%
from tensorflow.keras import losses

# %% [markdown]
# ### For data preprocessing

# %%
from tensorflow.keras import datasets
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# # 匯入 MNIST 資料集

# %% [markdown]
# #### load dataset

# %%
(X_train, y_train0), (X_test, y_test0) = datasets.mnist.load_data()

# %% [markdown]
# #### reshape size

# %%
X_train = X_train.reshape(-1, 28*28)
X_test = X_test.reshape(-1, 28*28)

# %% [markdown]
# #### normalize the range of feature

# %%
X_train = X_train / X_train.max()
X_test = X_test / X_test.max()

# %% [markdown]
# #### one-hot encoding

# %%
y_train = to_categorical(y_train0, 10)
y_test = to_categorical(y_test0, 10)

# %% [markdown]
# # 建立 VAE

# %%
enc_1 = Dense(512, activation='sigmoid')
enc_2 = Dense(256, activation='relu')
enc_3 = Dense(64, activation='sigmoid')
# 建立三層 encoding 層

# %%
enc_mean = Dense(2)
enc_log_var = Dense(2)

# %%
dec_3 = Dense(100, activation='sigmoid')
dec_2 = Dense(350, activation='sigmoid')
dec_1 = Dense(784, activation='sigmoid')
# 建立三層 decoding 層

# %%
x = Input(shape=(784,))
enc_x = enc_3(enc_2(enc_1(x)))

z_mean = enc_mean(enc_x)
z_log_var = enc_log_var(enc_x)

# %% [markdown]
# # 定義抽樣函數

# %%
def sampling(args):
    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    # by default, random_normal has mean = 0 and std = 1.0
    epsilon = K.random_normal(shape=(batch, dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# #### Sampling function wrapped as a Keras layer

# %%
z = Lambda(sampling, output_shape=(2,))([z_mean, z_log_var])

# %% [markdown]
# #### Define Decoder part of VAE

# %%
z_input = Input(shape=(2,))
x_hat = dec_1(dec_2(dec_3(z_input)))

# %% [markdown]
# ### 觀察資料長相

# %%
x_hat = dec_1(dec_2(dec_3(z)))

VAE = Model(x, x_hat)
VAE.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 784)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          401920      input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          131328      dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           16448       dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            130         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 2)            130         dense_2[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 2)            0           dense_3[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 100)          300         lambda[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 350)          35350       dense_5[1][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 784)          275184      dense_6[1][0]
# ==================================================================================================
# Total params: 860,790
# Trainable params: 860,790
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # 建立 loss function

# %%
# reconstruction_loss = tf.keras.losses.mse(inputs, outputs)
reconstruction_loss = 784 * losses.mean_squared_error(x, x_hat)

kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)

VAE.add_loss(vae_loss)

# %%
VAE.compile(optimizer=Adam())
# Out:
# WARNING:tensorflow:Output dense_7 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to dense_7.

# %% [markdown]
# # 訓練資料

# %%
VAE.fit(X_train, batch_size=300, epochs=15)
# batch size = 300
# 訓練 15 次
# Out:
# Train on 60000 samples
# Epoch 1/15
# 60000/60000 [==============================] - 3s 42us/sample - loss: 56.1961
# Epoch 2/15
# 60000/60000 [==============================] - 2s 35us/sample - loss: 52.8603
# Epoch 3/15
# 60000/60000 [==============================] - 2s 35us/sample - loss: 52.4454
# Epoch 4/15
# 60000/60000 [==============================] - 2s 37us/sample - loss: 49.3310
# Epoch 5/15
# 60000/60000 [==============================] - 2s 38us/sample - loss: 48.5130
# Epoch 6/15
# 60000/60000 [==============================] - 2s 36us/sample - loss: 47.9145
# Epoch 7/15
# 60000/60000 [==============================] - 2s 36us/sample - loss: 47.5558
# Epoch 8/15
# 60000/60000 [==============================] - 2s 37us/sample - loss: 46.9952
# Epoch 9/15
# 60000/60000 [==============================] - 2s 36us/sample - loss: 46.3858
# Epoch 10/15
# 60000/60000 [==============================] - 2s 38us/sample - loss: 45.8153
# Epoch 11/15
# 60000/60000 [==============================] - 2s 38us/sample - loss: 45.3072
# Epoch 12/15
# 60000/60000 [==============================] - 2s 36us/sample - loss: 44.7726
# Epoch 13/15
# 60000/60000 [==============================] - 2s 36us/sample - loss: 44.2950
# Epoch 14/15
# 60000/60000 [==============================] - ETA: 0s - loss: 43.89 - 2s 35us/sample - loss: 43.8720
# Epoch 15/15
# 60000/60000 [==============================] - 2s 35us/sample - loss: 43.5871

# %% [markdown]
# #  視覺化

# %%
VAE_Encoder = Model(x, z)
VAE_Encoder.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 784)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          401920      input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          131328      dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           16448       dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            130         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 2)            130         dense_2[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 2)            0           dense_3[0][0]
#                                                                  dense_4[0][0]
# ==================================================================================================
# Total params: 549,956
# Trainable params: 549,956
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
indices = np.random.randint(X_train.shape[0], size=7777)
VAE_latents = VAE_Encoder.predict(X_train[indices])

# %%
plt.figure(figsize=(15, 5))
plt.scatter(VAE_latents[:, 0], VAE_latents[:, 1], c=y_train0[indices], cmap='plasma')
plt.colorbar()
plt.show()

# %% [markdown]
# #### Decoder

# %%
VAE_Decoder = Model(z_input, dec_1(dec_2(dec_3(z_input))))

VAE_Decoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               300
# _________________________________________________________________
# dense_6 (Dense)              (None, 350)               35350
# _________________________________________________________________
# dense_7 (Dense)              (None, 784)               275184
# =================================================================
# Total params: 310,834
# Trainable params: 310,834
# Non-trainable params: 0
# _________________________________________________________________

# %%
def normalized(x):
    x -= x.min()
    x /= x.max()
    return x

# %%
n = 17  
#每排有多少點
digit_size = 28

grid_x_vae = np.linspace(-4+0.05, 4-0.05, n)
grid_y_vae = np.linspace(-4+0.05, 4-0.05, n)
VAE_figure = np.zeros((digit_size * n, digit_size * n))
for i, yi in enumerate(grid_x_vae):
    for j, xi in enumerate(grid_y_vae):
        z_sample = np.array([[xi, yi]])
        x_decoded = VAE_Decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        VAE_figure[(n-i-1) * digit_size: (n - i) * digit_size,
                   j * digit_size: (j + 1) * digit_size] = normalized(digit)

# %%
plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
XXX, YYY = np.meshgrid(grid_x_vae, grid_y_vae)
plt.scatter(XXX, YYY)

plt.subplot(1, 2, 2)
plt.imshow(VAE_figure, cmap='cividis')
plt.axis('off')
plt.show()
