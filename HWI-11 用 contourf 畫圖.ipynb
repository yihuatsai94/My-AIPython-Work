# %%
# %matplotlib inline
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# %%
def f(x, y):
    return (1 - x / 2 + x**5 + y**3) * np.exp(- x**2 - y**2)

x = np.linspace(-2, 4, 100)
y = np.linspace(-2, 4, 100)

X, Y = np.meshgrid(x, y)

plt.contourf(X, Y, f(X, Y), 5, alpha = 0.75, cmap = plt.cm.hot)
C = plt.contour(X, Y, f(X, Y), 5, colors = 'black', linewidth = 0.3)
plt.clabel(C, inline = True, fontsize =12)
# Out:
# /Users/saiyoroshikaba/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   # Remove the CWD from sys.path while we load stuff.
# <a list of 5 text.Text objects>
